# %%
import pandas as pd

path = r"C:\Users\user\Downloads\archive (7).zip"
df = pd.read_csv(path)
print(df.head())
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
print (df.isnull())
# Out:
#       Category  Price  Rating  Stock  Discount
# 0         True  False   False   True     False
# 1         True  False   False   True     False
# 2         True  False    True  False     False
# 3         True  False   False   True     False
# 4         True  False    True  False     False
# ...        ...    ...     ...    ...       ...
# 4357      True  False   False   True     False
# 4358     False  False    True  False     False
# 4359      True  False    True  False     False
# 4360     False  False   False   True     False
# 4361      True   True   False   True     False
#
# [4362 rows x 5 columns]

# %%
print(df.isnull().sum())
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %%
df['Discount'] =df['Discount'].fillna(df['Discount'].mean())
print(df)
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0       NaN      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0       NaN  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359      NaN  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
print("Mean Discount:",df['Discount'].mean())
# Out:
# Mean Discount: 24.516624685138538

# %%
import pandas as pd

path = r"C:\Users\user\Downloads\archive (7).zip"
df['Price'] =df['Price'].fillna(df['Price'].median())
print(df)
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0       NaN      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0       NaN  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359      NaN  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN  4996.5  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
df['Stock'] = df['Stock'].ffill()
print("\nAfter Forward Fill:")
print(df)
# Out:
# After Forward Fill:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0       NaN      In Stock       0.0
# 3         NaN  4808.0  1.492085      In Stock      33.0
# 4         NaN  1817.0       NaN  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335  Out of Stock      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359      NaN  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995  Out of Stock      40.0
# 4361      NaN  4996.5  2.184471  Out of Stock       0.0
#
# [4362 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Stock_Encoded']= encoder.fit_transform(df['Stock'])
print(df)
# Out:
#      Category   Price    Rating         Stock  Discount  Stock_Encoded
# 0         NaN  5548.0  1.870322           NaN       0.0              2
# 1         NaN  3045.0  4.757798           NaN      38.0              2
# 2         NaN  4004.0       NaN      In Stock       0.0              0
# 3         NaN  4808.0  1.492085      In Stock      33.0              0
# 4         NaN  1817.0       NaN  Out of Stock      23.0              1
# ...       ...     ...       ...           ...       ...            ...
# 4357      NaN  4436.0  4.728335  Out of Stock      49.0              1
# 4358        B  6236.0       NaN  Out of Stock       4.0              1
# 4359      NaN  3283.0       NaN  Out of Stock       9.0              1
# 4360        D  2999.0  4.425995  Out of Stock      40.0              1
# 4361      NaN  4996.5  2.184471  Out of Stock       0.0              1
#
# [4362 rows x 6 columns]

# %%
encoded_df = pd.get_dummies(df,columns=['Stock'])
print(encoded_df)
# Out:
#      Category   Price    Rating  Discount  Stock_Encoded  Stock_In Stock  \
# 0         NaN  5548.0  1.870322       0.0              2           False
# 1         NaN  3045.0  4.757798      38.0              2           False
# 2         NaN  4004.0       NaN       0.0              0            True
# 3         NaN  4808.0  1.492085      33.0              0            True
# 4         NaN  1817.0       NaN      23.0              1           False
# ...       ...     ...       ...       ...            ...             ...
# 4357      NaN  4436.0  4.728335      49.0              1           False
# 4358        B  6236.0       NaN       4.0              1           False
# 4359      NaN  3283.0       NaN       9.0              1           False
# 4360        D  2999.0  4.425995      40.0              1           False
# 4361      NaN  4996.5  2.184471       0.0              1           False
#
#       Stock_Out of Stock
# 0                  False
# 1                  False
# ...

# %%
encoded_df = pd.get_dummies(
    df,
    columns=['Stock'],
    dtype=int
)
print(encoded_df)
# Out:
#      Category   Price    Rating  Discount  Stock_Encoded  Stock_In Stock  \
# 0         NaN  5548.0  1.870322       0.0              2               0
# 1         NaN  3045.0  4.757798      38.0              2               0
# 2         NaN  4004.0       NaN       0.0              0               1
# 3         NaN  4808.0  1.492085      33.0              0               1
# 4         NaN  1817.0       NaN      23.0              1               0
# ...       ...     ...       ...       ...            ...             ...
# 4357      NaN  4436.0  4.728335      49.0              1               0
# 4358        B  6236.0       NaN       4.0              1               0
# 4359      NaN  3283.0       NaN       9.0              1               0
# 4360        D  2999.0  4.425995      40.0              1               0
# 4361      NaN  4996.5  2.184471       0.0              1               0
#
#       Stock_Out of Stock
# 0                      0
# 1                      0
# ...
